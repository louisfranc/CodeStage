# %%
import pandas as pd

df = pd.read_csv("pokemon_data.csv")
print(df.tail(3))
# Out:
#        #                 Name   Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 797  720  HoopaHoopa Confined  Psychic  Ghost  80     110       60      150
# 798  720   HoopaHoopa Unbound  Psychic   Dark  80     160       60      170
# 799  721            Volcanion     Fire  Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 797      130     70           6       True
# 798      130     80           6       True
# 799       90     70           6       True

# %% [markdown]
# # Reading headers

# %%
#permet d'avoir tout les nom des titres
#print(df.columns)
#print(df)

#pour lire chaque colonne
#print(df[["Name","Generation"]])

#lire chaque rangée, fonction iloc
#print(df.iloc[1:4])

#avoir une rangée spécifique(R,C)

#print(df.iloc[2,1])


#Get une rangée par itération, permet voir tout les données
#for index, row in df.iterrows():
   # print(index, row[["Name"]])
    
#df.loc[df[ "Type 1"] == "Fire"]
#df.loc[df[ "Type 2"] == "Psychic"]

# %% [markdown]
# # Descriptions et triage

# %%
df.sort_values(["Type 1","HP"],ascending=[1,0])
# Out:
#        #                     Name Type 1    Type 2  HP  Attack  Defense  \
# 520  469                  Yanmega    Bug    Flying  86      76       86
# 698  637                Volcarona    Bug      Fire  85      60       65
# 231  214                Heracross    Bug  Fighting  80     125       75
# 232  214  HeracrossMega Heracross    Bug  Fighting  80     185      115
# 678  617                 Accelgor    Bug       NaN  80      70       40
# ..   ...                      ...    ...       ...  ..     ...      ...
# 106   98                   Krabby  Water       NaN  30     105       90
# 125  116                   Horsea  Water       NaN  30      40       70
# 129  120                   Staryu  Water       NaN  30      45       55
# 139  129                 Magikarp  Water       NaN  20      10       55
# 381  349                   Feebas  Water       NaN  20      15       20
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %% [markdown]
# # Ajouter des données

# %%
print(df.columns)
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
df ["Total"] = df["HP"] + df["Attack"] + df["Defense"] + df["Sp. Atk"] + df["Sp. Def"] + df["Speed"] 

df.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0       65     45           1      False    318
# 1       80     60           1      False    405
# 2      100     80           1      False    525
# 3      120     80           1      False    625
# 4       50     65           1      False    309

# %%
df.sort_values(["Total"], ascending=False)
# Out:
#        #                   Name   Type 1    Type 2   HP  Attack  Defense  \
# 426  384  RayquazaMega Rayquaza   Dragon    Flying  105     180      100
# 164  150    MewtwoMega Mewtwo Y  Psychic       NaN  106     150       70
# 163  150    MewtwoMega Mewtwo X  Psychic  Fighting  106     190      100
# 422  382    KyogrePrimal Kyogre    Water       NaN  100     150       90
# 424  383  GroudonPrimal Groudon   Ground      Fire  100     180      160
# ..   ...                    ...      ...       ...  ...     ...      ...
# 13    10               Caterpie      Bug       NaN   45      30       35
# 288  265                Wurmple      Bug       NaN   45      45       35
# 446  401              Kricketot      Bug       NaN   37      25       41
# 322  298                Azurill   Normal     Fairy   50      20       40
# 206  191                Sunkern    Grass       NaN   30      30       30
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# ...

# %%
#Créer la colonne total
df["Total"] = df.iloc[:, 4:10].sum(axis=1)
df.head(10)
# Out:
#    #                       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1                  Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                    Ivysaur  Grass  Poison  60      62       63       80
# 2  3                   Venusaur  Grass  Poison  80      82       83      100
# 3  3      VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4                 Charmander   Fire     NaN  39      52       43       60
# 5  5                 Charmeleon   Fire     NaN  58      64       58       80
# 6  6                  Charizard   Fire  Flying  78      84       78      109
# 7  6  CharizardMega Charizard X   Fire  Dragon  78     130      111      130
# 8  6  CharizardMega Charizard Y   Fire  Flying  78     104       78      159
# 9  7                   Squirtle  Water     NaN  44      48       65       50
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0       65     45           1      False    318
# ...

# %% [markdown]
# ARRANGER DES COLONNES

# %%
cols = list(df.columns.values)
df = df[cols[0:4] + [cols[-1]] + cols[4:12]]

df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %% [markdown]
# # Sauvegarder les données

# %%
df.to_csv("modified.csv", index=False)

# %% [markdown]
# # Data filtering

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
#new_df = df.loc[(df["Type 1"] == "Fire") & (df["Type 2"] == "Flying") & (df["HP"]>70) ] 
#new_df.head()

#new_df.reset_index(drop=True, inplace=True )

#new_df

# %%
#Filter out all the mega
#df.loc[df["Type 1"].str.contains("Fire|Grass", regex=True)]

# %%
#Permet de dire les première lettres
df.loc[df["Name"].str.contains("pi[a-z]*",regex=True)]

#APPRENDRE REGEX
# Out:
#        #        Name   Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 13    10    Caterpie      Bug     NaN    195   45      30       35       20
# 42    37      Vulpix     Fire     NaN    299   38      41       40       50
# 76    70  Weepinbell    Grass  Poison    390   65      90       50       85
# 84    78    Rapidash     Fire     NaN    500   65     100       70       80
# 181  167    Spinarak      Bug  Poison    250   40      60       40       40
# 189  175      Togepi    Fairy     NaN    245   35      20       65       40
# 202  187      Hoppip    Grass  Flying    250   35      35       40       35
# 266  247     Pupitar     Rock  Ground    410   70      84       70       65
# 345  316      Gulpin   Poison     NaN    302   70      43       53       43
# 357  326     Grumpig  Psychic     NaN    470   80      45       65       90
# 358  327      Spinda   Normal     NaN    360   60      60       60       60
# ...

# %% [markdown]
# # CONDITIONNAL CHANGES

# %%
#Changer des données dans le tableau
df.loc[df["Type 1"] == "Flamer", "Type 1"] = "Fire"

df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
#Changer pour qu'un nom de données sois toujours associés au même. 
df.loc[df["Type 1"] == "Fire", "Legendary"] = False
df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %% [markdown]
# # CONDITIONNAL CHANGES

# %%
#df["Total"] = df.iloc[:, 4:10].sum(axis=1)
#df.loc[df["Total"] > 500, ["Generation", "Legendary",]]= "Test Value"
#df

# %% [markdown]
# ## "GROUP BY" statistiques

# %%
#Avoir la moyenne d'un titre

df.groupby(["Type 1"]).mean().sort_values("HP", ascending=False)
# Out:
#                    #       Total         HP      Attack     Defense  \
# Type 1
# Dragon    474.375000  550.531250  83.312500  112.125000   86.375000
# Normal    319.173469  401.683673  77.275510   73.469388   59.846939
# Fairy     449.529412  413.176471  74.117647   61.529412   65.705882
# Ground    356.281250  437.500000  73.781250   95.750000   84.843750
# Water     303.089286  430.455357  72.062500   74.151786   72.946429
# Ice       423.541667  433.458333  72.000000   72.750000   71.416667
# Flying    677.750000  485.000000  70.750000   78.750000   66.250000
# Psychic   380.807018  475.947368  70.631579   71.456140   67.684211
# Fire      327.403846  458.076923  69.903846   84.769231   67.769231
# Fighting  363.851852  416.444444  69.851852   96.777778   65.925926
# Grass     344.871429  421.142857  67.271429   73.214286   70.800000
# Poison    251.785714  399.142857  67.250000   74.678571   68.821429
# Dark      461.354839  445.741935  66.806452   88.387097   70.225806
# ...

# %%
#Grouper par sommation d'un élément avec même groupe

df["count"] = 1
df.groupby(["Type 1","Type 2"]).count()["count"]
# Out:
# Type 1  Type 2
# Bug     Electric     2
#         Fighting     2
#         Fire         2
#         Flying      14
#         Ghost        1
#                     ..
# Water   Ice          3
#         Poison       3
#         Psychic      5
#         Rock         4
#         Steel        1
# Name: count, Length: 136, dtype: int64

# %% [markdown]
# # Travailler avec grosse database

# %%
#Permet de travailler par "chunk" de data
for df in pd.read_csv("modified.csv", chunk 5 = 4)


#à revoir, non pertinent
