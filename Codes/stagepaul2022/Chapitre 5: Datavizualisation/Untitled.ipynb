# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Line plot de base
import matplotlib.pyplot as plt
import numpy as np
import math

x_vals=np.linspace(0,20,20)
y_vals=[math.sqrt(i) for i in x_vals]
plt.plot(x_vals,y_vals)

# %%
import matplotlib.pyplot as plt
import numpy as np
import math

x_vals = np.linspace(0,20,20)
y_vals = [math.sqrt(i) for i in x_vals]

fig=plt.figure()
ax = plt.axes()
ax.plot(x_vals,y_vals)

# %%
#adding titles
import matplotlib.pyplot as plt
import numpy as np
import math

x_vals = np.linspace(0,20,20)
y_vals=[math.sqrt(i) for i in x_vals]

plt.xlabel("Valeur en X")
plt.ylabel("Valeur en Y")
plt.title("Graphique 1")
plt.plot(x_vals,y_vals)

# %%
#ajouter des couleurs
import matplotlib.pyplot as plt
import numpy as np
import math

x_vals=np.linspace(0,20,20)
y_vals=[math.sqrt(i) for i in x_vals]

plt.xlabel("Valeur en X")
plt.ylabel("Valeur en Y")
plt.title("Graphique 2 de couleur")
plt.plot(x_vals,y_vals,"r")

# %%
### Ajout d'une légende

import matplotlib.pyplot as plt
import numpy as np
import math

x_vals=np.linspace(0,20,20)
y_vals=[math.sqrt(i) for i in x_vals]

plt.xlabel("Valeur en x")
plt.ylabel("Valeur en y")
plt.title("Graphique 3, couleur et légende")
plt.plot(x_vals,y_vals,"r",label="square root")
plt.legend(loc="upper center")

# %%
#Ajout d'un deuxième graphique
import matplotlib.pyplot as plt
import numpy as np
import math

x_vals=np.linspace(0,20,20)
y_vals=[math.sqrt(i) for i in x_vals]
y2_vals= x_vals**3

plt.xlabel("X values")
plt.ylabel("Y values")
plt.title("Square roots")
plt.plot(x_vals,y_vals,"r",label="Square Root")
plt.plot(x_vals,y2_vals,"b",label="Cube")
plt.legend(loc="upper center")
